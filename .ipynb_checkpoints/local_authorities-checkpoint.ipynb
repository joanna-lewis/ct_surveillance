# %% [markdown]
# # Predicting regional differences in proportion diagnosed and positivity
#
# In this example, we assume that the incidence of chlamydia is homoegeneous across England and investigate whether the differences in testing rates could explain differences in diagnoses and positivity.
#
# We begin by sampling a distribution for the incidence in men and women in the country overall. This is done by the script prev_inc_dist, using the same method illustrated in `england.ipynb`.

# %%
# this script contains the functions for observed testing and diagnosis rates
# running this script takes a little while because of all the symbolic algebra
# %run -i test_diag_fun.py

# this script provides a function for calculating the likelihood of categorical data
# %run -i multinomial_pmf.py

# this script gets the posterior distributions for nationwide prevalence and incidence
# takes quite a long time because of all the sampling and solving 
# %run -i prev_inc_dist.py

who()
# Out:
# 0.4661
# 0.3363
# 0.3668
# 0.2642
# Name                    Shape            Bytes            Type
# ===================================================================
#
# simp_old                5                40               float64
# p_true_pos_f            10000            80000            float64
# p_true_pos_m            10000            80000            float64
# inc_m_15_24             10000            80000            float64
# scr_m_15_24             10000            80000            float64
# test_rate_m_15_24       10000            80000            float64
# p_active_m_16_24        10000            80000            float64
# inc_f_15_24             10000            80000            float64
# scr_f_15_24             10000            80000            float64
# att_symp_f              10000            80000            float64
# att_symp_m              10000            80000            float64
# p_asymp_f               10000            80000            float64
# p_asymp_m               10000            80000            float64
# p_active_f_16_24        10000            80000            float64
# ll_f                    10000            80000            float64
# ll_m                    10000            80000            float64
# simp_new                5                40               float64
# prev_m_15_24            10000            80000            float64
# test_rate_f_15_24       10000            80000            float64
# pop_active_f_15_24      10000            80000            int64
# prev_f_15_24            10000            80000            float64
# sc_f                    10000            80000            float64
# p_false_pos_f           10000            80000            float64
# p_false_pos_m           10000            80000            float64
# diag_rate_m_15_24       10000            80000            float64
# pop_active_m_15_24      10000            80000            int64
# diag_rate_f_15_24       10000            80000            float64
# sc_m                    10000            80000            float64
#
# Upper bound on total bytes  =       2080080

# %%
n_sample
# Out:
# 10000

# %% [markdown]
# Surveillance data on chlamydia testing and diagnosis rates by English local authority 2012 were downloaded from: http://www.chlamydiascreening.nhs.uk/ps/data.asp (downloaded 17 April 2015).

# %%
# now read in the regional (upper-tier local authority) testing and diagnosis rates
import pandas as pd
from pandas import *
pd.options.mode.chained_assignment = None  # default='warn'

alldata = pd.read_csv('2012_age_sex_region.csv')
alldata = alldata[alldata.laut != 'Isles of Scilly'] # remove Scilly Isles because of small numbers
alldata.index = range(len(alldata))
alldata

# laut: Local Authority Upper Tier
# gor: Government Office Region
# phec: Public Health England Region
# pher: Public Health England Centre
# Out:
#      laut_code                    laut         gor  \
# 0    E09000002    Barking and Dagenham      london
# 1    E09000003                  Barnet      london
# 2    E09000004                  Bexley      london
# 3    E09000005                   Brent      london
# 4    E09000006                 Bromley      london
# 5    E09000007                  Camden      london
# 6    E09000001          City of London      london
# 7    E09000008                 Croydon      london
# 8    E09000009                  Ealing      london
# 9    E09000010                 Enfield      london
# 10   E09000011               Greenwich      london
# 11   E09000012                 Hackney      london
# 12   E09000013  Hammersmith and Fulham      london
# 13   E09000014                Haringey      london
# 14   E09000015                  Harrow      london
# 15   E09000016                Havering      london
# 16   E09000017              Hillingdon      london
# 17   E09000018                Hounslow      london
# 18   E09000019               Islington      london
# 19   E09000020  Kensington and Chelsea      london
# 20   E09000021    Kingston upon Thames      london
# 21   E09000022                 Lambeth      london
# 22   E09000023                Lewisham      london
# 23   E09000024                  Merton      london
# 24   E09000025                  Newham      london
# 25   E09000026               Redbridge      london
# 26   E09000027    Richmond upon Thames      london
# 27   E09000028               Southwark      london
# 28   E09000029                  Sutton      london
# 29   E09000030           Tower Hamlets      london
# ..         ...                     ...         ...
# 121  E06000024          North Somerset  south west
# 122  E06000025   South Gloucestershire  south west
# 123  E06000030                 Swindon  south west
# 124  E06000054               Wiltshire  south west
# 125  E06000052                Cornwall  south west
# 126  E10000008                   Devon  south west
# 127  E06000026                Plymouth  south west
# 128  E10000027                Somerset  south west
# 129  E06000027                  Torbay  south west
# 130  E06000028             Bournemouth  south west
# 131  E10000009                  Dorset  south west
# 132  E10000014               Hampshire  south east
# 133  E06000046           Isle of Wight  south east
# 134  E06000029                   Poole  south west
# 135  E06000044              Portsmouth  south east
# 136  E06000045             Southampton  south east
# 137  E06000043       Brighton and Hove  south east
# 138  E10000011             East Sussex  south east
# 139  E10000016                    Kent  south east
# 140  E06000035                  Medway  south east
# 141  E10000030                  Surrey  south east
# 142  E10000032             West Sussex  south east
# 143  E06000036        Bracknell Forest  south east
# 144  E10000002         Buckinghamshire  south east
# 145  E10000025             Oxfordshire  south east
# 146  E06000038                 Reading  south east
# 147  E06000039                  Slough  south east
# 148  E06000037          West Berkshire  south east
# 149  E06000040  Windsor and Maidenhead  south east
# 150  E06000041               Wokingham  south east
#
#                                   phec              pher  tests.male.15-19  \
# 0                               London            London              1741
# 1                               London            London               491
# 2                               London            London               631
# 3                               London            London              1209
# 4                               London            London              1049
# 5                               London            London              1225
# 6                               London            London                12
# 7                               London            London              1570
# 8                               London            London              1126
# 9                               London            London               609
# 10                              London            London              2315
# 11                              London            London               969
# 12                              London            London               290
# 13                              London            London               958
# 14                              London            London               408
# 15                              London            London              1285
# 16                              London            London              2379
# 17                              London            London              1990
# 18                              London            London               421
# 19                              London            London               314
# 20                              London            London               591
# 21                              London            London              1680
# 22                              London            London              1537
# 23                              London            London               555
# 24                              London            London              1697
# 25                              London            London              1559
# 26                              London            London               449
# 27                              London            London              1152
# 28                              London            London               617
# 29                              London            London              1668
# ..                                 ...               ...               ...
# 121  Avon, Gloucestershire & Wiltshire  South of England               631
# 122  Avon, Gloucestershire & Wiltshire  South of England              1003
# 123  Avon, Gloucestershire & Wiltshire  South of England               569
# 124  Avon, Gloucestershire & Wiltshire  South of England              1047
# 125         Devon, Cornwall & Somerset  South of England              1669
# 126         Devon, Cornwall & Somerset  South of England              2240
# 127         Devon, Cornwall & Somerset  South of England               541
# 128         Devon, Cornwall & Somerset  South of England              1256
# 129         Devon, Cornwall & Somerset  South of England               505
# 130                             Wessex  South of England              1241
# 131                             Wessex  South of England              1725
# 132                             Wessex  South of England              7589
# 133                             Wessex  South of England               566
# 134                             Wessex  South of England               507
# 135                             Wessex  South of England              2749
# 136                             Wessex  South of England              1917
# 137              Kent, Surrey & Sussex  South of England              2499
# 138              Kent, Surrey & Sussex  South of England              1257
# 139              Kent, Surrey & Sussex  South of England              6485
# 140              Kent, Surrey & Sussex  South of England               700
# 141              Kent, Surrey & Sussex  South of England              1827
# 142              Kent, Surrey & Sussex  South of England              1437
# 143                      Thames Valley  South of England               120
# 144                      Thames Valley  South of England               698
# 145                      Thames Valley  South of England              1573
# 146                      Thames Valley  South of England              1392
# 147                      Thames Valley  South of England               186
# 148                      Thames Valley  South of England               125
# 149                      Thames Valley  South of England               135
# 150                      Thames Valley  South of England               216
#
#      tests.male.20-24  tests.male.total  tests.female.15-19  \
# 0                1466              3207                2354
# 1                1514              2005                1568
# 2                 990              1621                1355
# 3                2818              4027                2478
# 4                1278              2327                1935
# 5                2310              3535                3182
# 6                  25                37                  12
# 7                2360              3930                3442
# 8                1811              2937                1842
# 9                1353              1962                1852
# 10               3061              5376                2939
# 11               3068              4037                2852
# 12               1446              1736                 872
# 13               2679              3637                2499
# 14                827              1235                 863
# 15               1350              2635                2530
# 16               2413              4792                3053
# 17               1769              3759                1831
# 18               1895              2316                1292
# 19               1118              1432                 717
# 20               1348              1939                1339
# 21               5704              7384                4612
# 22               3239              4776                4075
# 23               1200              1755                1078
# 24               3283              4980                2791
# 25               1583              3142                2334
# 26                941              1390                1039
# 27               3592              4744                3180
# 28               1115              1732                1554
# 29               3294              4962                1515
# ..                ...               ...                 ...
# 121               858              1489                2366
# 122              1197              2200                2802
# 123               897              1466                2134
# 124              2123              3170                3509
# 125              3099              4768                5072
# 126              4486              6720                6648
# 127              1640              2181                1816
# 128              2186              3442                4280
# 129               686              1191                1483
# 130              2000              3241                2684
# 131              2096              3821                3330
# 132              6691             14280               14306
# 133               807              1373                1647
# 134               587              1094                1292
# 135              4164              6913                4968
# 136              2621              4538                3549
# 137              5821              8320                5970
# 138              2049              3306                4506
# 139              6882             13367               15695
# 140              1048              1748                1899
# 141              4113              5940                5440
# 142              2723              4160                4203
# 143               308               428                 509
# 144              1477              2175                1792
# 145              3319              4892                4125
# 146              1924              3316                3125
# 147               529               715                 757
# 148               446               571                 439
# 149               365               500                 531
# 150               481               697                 562
#
#      tests.female.20-24        ...         positives.female.20-24  \
# 0                  2811        ...                            174
# 1                  3591        ...                            232
# 2                  1795        ...                            121
# 3                  5259        ...                            331
# 4                  2573        ...                            139
# 5                  6368        ...                            341
# 6                    88        ...                              5
# 7                  4996        ...                            392
# 8                  3359        ...                            204
# 9                  3732        ...                            193
# 10                 4281        ...                            246
# 11                 7018        ...                            398
# 12                 2939        ...                            196
# 13                 5641        ...                            441
# 14                 1628        ...                            112
# 15                 2457        ...                            130
# 16                 3881        ...                            186
# 17                 2936        ...                            182
# 18                 4546        ...                            259
# 19                 2113        ...                            121
# 20                 2884        ...                            191
# 21                10997        ...                            827
# 22                 7596        ...                            498
# 23                 2128        ...                            118
# 24                 5580        ...                            343
# 25                 3003        ...                            151
# 26                 1856        ...                             98
# 27                 7446        ...                            472
# 28                 1960        ...                            120
# 29                 5537        ...                            298
# ..                  ...        ...                            ...
# 121                2520        ...                            190
# 122                3265        ...                            215
# 123                2177        ...                            175
# 124                4398        ...                            328
# 125                6372        ...                            462
# 126                8392        ...                            560
# 127                3370        ...                            239
# 128                5409        ...                            352
# 129                1520        ...                            148
# 130                3608        ...                            205
# 131                3319        ...                            167
# 132               13296        ...                            817
# 133                1729        ...                            106
# 134                1513        ...                             74
# 135                5911        ...                            285
# 136                4935        ...                            256
# 137               10062        ...                            553
# 138                5417        ...                            312
# 139               15569        ...                            955
# 140                2439        ...                            177
# 141                8821        ...                            532
# 142                6013        ...                            414
# 143                 645        ...                             39
# 144                2776        ...                            184
# 145                6389        ...                            318
# 146                4225        ...                            258
# 147                1190        ...                             84
# 148                 854        ...                             64
# 149                 782        ...                             56
# 150                 951        ...                             60
#
#      positives.female.total  positives.total.15-19  positives.total.20-24  \
# 0                       407                    317                    284
# 1                       380                    194                    370
# 2                       255                    189                    201
# 3                       565                    333                    560
# 4                       277                    199                    249
# 5                       585                    358                    525
# 6                         7                      2                      7
# 7                       809                    563                    679
# 8                       333                    177                    346
# 9                       329                    180                    273
# 10                      516                    389                    511
# 11                      696                    420                    683
# 12                      293                    126                    336
# 13                      775                    507                    800
# 14                      197                    122                    202
# 15                      281                    205                    214
# 16                      370                    263                    325
# 17                      334                    260                    355
# 18                      372                    160                    462
# 19                      185                     87                    209
# 20                      280                    115                    289
# 21                     1509                    992                   1474
# 22                      952                    671                    859
# 23                      217                    132                    246
# 24                      632                    411                    579
# 25                      321                    241                    240
# 26                      133                     46                    161
# 27                      850                    555                    851
# 28                      252                    168                    223
# 29                      426                    161                    504
# ..                      ...                    ...                    ...
# 121                     386                    240                    288
# 122                     423                    266                    329
# 123                     413                    312                    299
# 124                     639                    399                    574
# 125                     883                    533                    800
# 126                    1240                    908                   1022
# 127                     424                    270                    438
# 128                     685                    435                    585
# 129                     337                    256                    266
# 130                     397                    266                    379
# 131                     374                    289                    342
# 132                    1707                   1211                   1433
# 133                     182                    109                    190
# 134                     160                    112                    134
# 135                     534                    353                    548
# 136                     425                    235                    464
# 137                     968                    526                    968
# 138                     670                    464                    537
# 139                    2005                   1399                   1596
# 140                     372                    264                    299
# 141                     932                    541                    911
# 142                     807                    554                    776
# 143                      76                     47                     82
# 144                     346                    219                    360
# 145                     567                    444                    743
# 146                     540                    412                    443
# 147                     159                     97                    146
# 148                     126                     68                    113
# 149                     105                     62                     92
# 150                     114                     80                    110
#
#      positives.total  population.male.15-19  population.male.20-24  \
# 0                601                   6672                   6484
# 1                564                  10694                  11651
# 2                390                   7850                   7582
# 3                893                   9809                  11764
# 4                448                   9289                   7845
# 5                883                   5915                  10708
# 6                  9                    113                    232
# 7               1242                  12161                  11330
# 8                523                   9660                  11740
# 9                453                  10808                  10346
# 10               900                   8189                  10306
# 11              1103                   6538                   9238
# 12               462                   3627                   7445
# 13              1307                   7201                   9335
# 14               324                   8092                   8004
# 15               419                   7724                   7619
# 16               588                   9607                  11788
# 17               615                   7589                   9181
# 18               622                   5008                   9284
# 19               296                   3115                   5070
# 20               404                   4589                   6734
# 21              2466                   7126                  11621
# 22              1530                   7905                   9888
# 23               378                   5451                   5696
# 24               990                  10067                  16711
# 25               481                   9229                   9692
# 26               207                   4438                   4103
# 27              1406                   7583                  12596
# 28               391                   5928                   5052
# 29               665                   7104                  13841
# ..               ...                    ...                    ...
# 121              528                   5888                   4675
# 122              595                   9269                   8129
# 123              611                   6413                   6159
# 124              973                  14819                  14009
# 125             1333                  16268                  14967
# 126             1930                  22951                  23342
# 127              708                   9045                  13296
# 128             1020                  17143                  14235
# 129              522                   3925                   3389
# 130              645                   5337                   9051
# 131              631                  12791                  10375
# 132             2644                  41296                  36364
# 133              299                   4387                   3578
# 134              246                   4342                   3962
# 135              901                   7560                  13361
# 136              699                   9025                  16104
# 137             1494                   8281                  15029
# 138             1001                  16072                  13487
# 139             2995                  48663                  45102
# 140              563                   9451                  10198
# 141             1452                  34786                  31245
# 142             1330                  24002                  20506
# 143              129                   3752                   3369
# 144              579                  16011                  13247
# 145             1187                  21137                  25274
# 146              855                   4680                   7111
# 147              243                   4508                   4434
# 148              181                   4968                   3708
# 149              154                   4464                   3483
# 150              190                   5004                   3921
#
#      population.female.15-19  population.female.20-24  population.total
# 0                       6137                     6532             25825
# 1                       9883                    11938             44166
# 2                       7705                     7709             30846
# 3                       8587                    11081             41241
# 4                       8810                     8460             34404
# 5                       5777                    12163             34563
# 6                        118                      263               726
# 7                      11377                    11696             46564
# 8                       8980                    11077             41457
# 9                       9714                    10974             41842
# 10                      7618                     9860             35973
# 11                      6776                    10428             32980
# 12                      3645                     7656             22373
# 13                      7015                     9153             32704
# 14                      7103                     7516             30715
# 15                      7492                     7618             30453
# 16                      8936                    10953             41284
# 17                      6981                     8728             32479
# 18                      5060                    10728             30080
# 19                      2936                     5097             16218
# 20                      4686                     7519             23528
# 21                      6895                    13205             38847
# 22                      7906                    10851             36550
# 23                      4877                     5882             21906
# 24                     10122                    13794             50694
# 25                      8767                     9140             36828
# 26                      4401                     4543             17485
# 27                      7397                    14748             42324
# 28                      5643                     5409             22032
# 29                      6980                    15222             43147
# ..                       ...                      ...               ...
# 121                     5543                     4723             20829
# 122                     8398                     7423             33219
# 123                     6101                     6256             24929
# 124                    14192                    11192             54212
# 125                    15542                    14431             61208
# 126                    21500                    21098             88891
# 127                     8740                    11638             42719
# 128                    15738                    13642             60758
# 129                     3571                     3279             14164
# 130                     5536                     8706             28630
# 131                    11256                     8732             43154
# 132                    38610                    34435            150705
# 133                     3897                     3216             15078
# 134                     4183                     3797             16284
# 135                     7165                    10983             39069
# 136                     8742                    14422             48293
# 137                     8241                    15338             46889
# 138                    15142                    13047             57748
# 139                    46460                    44672            184897
# 140                     8823                    10087             38559
# 141                    33047                    31433            130511
# 142                    22085                    20275             86868
# 143                     3491                     3005             13617
# 144                    15409                    13034             57701
# 145                    19902                    22428             88741
# 146                     4588                     7475             23854
# 147                     4178                     4448             17568
# 148                     4714                     3515             16905
# 149                     4053                     3239             15239
# 150                     4752                     3404             17081
#
# [151 rows x 28 columns]

# %% [markdown]
# We now infer percentage diagnosed and positivity in men and women by LAUT, given testing rate and assuming the national incidence.

# %%
# set up arrays to store, for each LAUT: 
test_sample_m = empty([n_sample, len(alldata)]) # testing rate
test_sample_f = empty([n_sample, len(alldata)])
diag_sample_m = empty([n_sample, len(alldata)]) # observed diagnosis rate
diag_sample_f = empty([n_sample, len(alldata)])
diag_m_laut = empty([n_sample, len(alldata)]) # predicted diagnosis rate
diag_f_laut = empty([n_sample, len(alldata)])
scr_m = empty([n_sample, len(alldata)]) # screening (assuming homogeneous incidence)
scr_f = empty([n_sample, len(alldata)])
scr_m_laut = empty([n_sample, len(alldata)]) # screening (estimated for each LAUT separately)
scr_f_laut = empty([n_sample, len(alldata)])
inc_m_laut = empty([n_sample, len(alldata)])  # estimated incidence
inc_f_laut = empty([n_sample, len(alldata)])
prev_m_laut = empty([n_sample, len(alldata)]) # estimated prevalence
prev_f_laut = empty([n_sample, len(alldata)])

for i in xrange(len(alldata.index)):
    
    # keep track of whether stuff is happening
    if fmod(i,10)==0:
        print i, alldata.laut[i]
    
    #####
    # men
    #####
    # sample for the testing rate, per sexually active 15-24-year-old
    test_sample_m[:,i] = random.gamma(alldata['tests.male.total'][i],1,size = n_sample)/ \
        random.binomial(alldata['population.male.15-19'][i] + alldata['population.male.20-24'][i], 
                        p_active_m_16_24, size=n_sample)
    diag_sample_m[:,i] = random.gamma(alldata['positives.male.total'][i],1,size = n_sample)/ \
        random.binomial(alldata['population.male.15-19'][i] + alldata['population.male.20-24'][i], 
                        p_active_m_16_24, size=n_sample)
        
    # screening and diagnosis rates
    for j in xrange(n_sample):
        # screening and predicted diagnoses, given national incidence (assumed homogeneous)
        [scr_m[j,i], diag_m_laut[j,i]] = fsolve(lambda x: test_diag_fun(concatenate([
                    array([inc_m_15_24[j], x[0]]), array([
                        1-p_asymp_m[j], # proportion of incident infections which are symptomatic
                        sc_m[j], # rate of self-clear 
                        att_symp_m[j],
                        p_true_pos_m[j], 
                        p_false_pos_m[j]
                        ])])) - array([test_sample_m[j,i], x[1]]), [0.3, 0.3])

        # local screening and incidence, given local testing and diagnoses
        [inc_m_laut[j,i], scr_m_laut[j,i]] = fsolve(lambda x: test_diag_fun(concatenate([
                        x, array([
                                1-p_asymp_m[j], # proportion of incident infections which are symptomatic
                                sc_m[j], # rate of self-clear 
                                att_symp_m[j],
                                p_true_pos_m[j], 
                                p_false_pos_m[j]
                            ])])) - array([test_sample_m[j,i],diag_sample_m[j,i]]), [0.09, 0.25])
        # local prevalence, calculated from local screening and incidence
        prev_m_laut[j,i] = dyn_fun(inc_m_laut[j,i]*p_asymp_m[j], sc_m[j] + scr_m_laut[j,i]*p_true_pos_m[j], inc_m_laut[j,i]*(1-p_asymp_m[j]), sc_m[j] + scr_m_laut[j,i]*p_true_pos_m[j] + att_symp_m[j]*p_true_pos_m[j])
    
    #####
    # women
    #####
    # sample for the testing rate, per sexually active 15-24-year-old
    test_sample_f[:,i] = random.gamma(alldata['tests.female.total'][i],1,size = n_sample)/ \
        random.binomial(alldata['population.female.15-19'][i] + alldata['population.female.20-24'][i], 
                        p_active_f_16_24, size=n_sample)
    diag_sample_f[:,i] = random.gamma(alldata['positives.female.total'][i],1,size = n_sample)/ \
        random.binomial(alldata['population.female.15-19'][i] + alldata['population.female.20-24'][i], 
                        p_active_f_16_24, size=n_sample)

    # screening and diagnosis rates
    diag_f_laut[:,i] = zeros(n_sample)
    for j in xrange(n_sample):
        [scr_f[j,i], diag_f_laut[j,i]] = fsolve(lambda x: test_diag_fun(concatenate([
                    array([inc_f_15_24[j], x[0]]), array([
                        1-p_asymp_f[j], # proportion of incident infections which are symptomatic
                        sc_f[j], # rate of self-clear 
                        att_symp_f[j],
                        p_true_pos_f[j], 
                        p_false_pos_f[j]
                        ])])) - array([test_sample_f[j,i], x[1]]), [0.3, 0.3])

        # local screening and incidence, given local testing and diagnoses
        [inc_f_laut[j,i], scr_f_laut[j,i]] = fsolve(lambda x: test_diag_fun(concatenate([
                        x, array([
                                1-p_asymp_f[j], # proportion of incident infections which are symptomatic
                                sc_f[j], # rate of self-clear 
                                att_symp_f[j],
                                p_true_pos_f[j], 
                                p_false_pos_f[j]
                            ])])) - array([test_sample_f[j,i],diag_sample_f[j,i]]), [0.09, 0.25])
        # local prevalence, calculated from local screening and incidence
        prev_f_laut[j,i] = dyn_fun(inc_f_laut[j,i]*p_asymp_f[j], sc_f[j] + scr_f_laut[j,i]*p_true_pos_f[j], inc_f_laut[j,i]*(1-p_asymp_f[j]), sc_f[j] + scr_f_laut[j,i]*p_true_pos_f[j] + att_symp_f[j]*p_true_pos_f[j])
# Out:
# 0 Barking and Dagenham
# 10 Greenwich
# 20 Kingston upon Thames
# 30 Waltham Forest
# 40 Derbyshire
# 50 Peterborough
# 60 Solihull
# 70 Halton
# 80 Lancashire
# 90 Wigan
# 100 South Tyneside
# 110 Leeds
# 120 Gloucestershire
# 130 Bournemouth
# 140 Medway
# 150 Wokingham
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/minpack.py:236: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
min(percentile(test_sample_m, 50, 0))
# Out:
# 0.062060747672616587

# %%
# plot testing and diagnosis rates to show correlation
import matplotlib.pyplot as plt
# %matplotlib inline

def plt_ppc(ax, xsample, ysample, index, ci, col): # ci is the confidence interval required, as a %
    ax.errorbar(percentile(xsample, 50, index), 
                percentile(ysample, 50, index), 
                xerr=squeeze(
                    array([[percentile(xsample,50, index) - percentile(xsample, (100.-ci)/2, index)], 
                           [percentile(xsample, (100.+ci)/2, index) - percentile(xsample,50, index)]])
            ), 
                yerr=squeeze(
                    array([[percentile(ysample,50, index) - percentile(ysample, (100.-ci)/2, index)], 
                           [percentile(ysample, (100.+ci)/2, index) - percentile(ysample,50, index)]])
            ),
                linestyle = 'None', color = col)

fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

plt_ppc(ax1, test_sample_m, diag_sample_m, 0, 95, 'b')
plt_ppc(ax2, test_sample_f, diag_sample_f, 0, 95, 'r')

ax1.set_title('Sexually active men, 15-24'); ax2.set_title('Sexually active women, 15-24')

ax1.set_xlabel('Proportion tested'); ax2.set_xlabel('Proportion tested')
ax1.set_ylabel('Proportion diagnosed'); ax2.set_ylabel('Proportion diagnosed')

ax1.set_xlim([0,1]); ax2.set_xlim([0,1])
ax1.set_ylim([0,0.1]); ax2.set_ylim([0,0.1])
# Out:
# (0, 0.1)

# %%
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.plot([0,1], [0,1], '0.5')
ax2.plot([0,1], [0,1], '0.5')

# positivity
pos_m_laut = diag_m_laut/test_sample_m

# add to plot
plt_ppc(ax1, diag_sample_m, diag_m_laut, 0, 95, 'b')
plt_ppc(ax2, diag_sample_m/test_sample_m, diag_m_laut/test_sample_m, 0, 95, 'b')

# positivity
pos_f_laut = diag_f_laut/test_sample_f

# add to plot
plt_ppc(ax1, diag_sample_f, diag_f_laut, 0, 95, 'r')
plt_ppc(ax2, diag_sample_f/test_sample_f, diag_f_laut/test_sample_f, 0, 95, 'r')

ax1.set_xlim([0,0.1]); ax1.set_ylim([0,0.1])
ax1.set_xlabel('Observed Diagnosis rate')
ax1.set_ylabel('Predicted Diagnosis rate')
ax2.set_xlim([0,0.25]); ax2.set_ylim([0,0.25])
ax2.set_xlabel('Observed Positivity')
ax2.set_ylabel('Predicted Positivity')

# %% [markdown]
# ## Regional variations in estimated prevalence
#
# The same sampled distributions can also be used to compare the estimated prevalence in different areas of the country. First, examine the correlation with positivity:

# %%
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

# positivity
pos_m_laut = diag_m_laut/test_sample_m
pos_f_laut = diag_f_laut/test_sample_f

# add to plot
plt_ppc(ax1, prev_m_laut, pos_m_laut, 0, 95, 'b')
plt_ppc(ax2, prev_f_laut, pos_f_laut, 0, 95, 'r')

ax1.set_xlim([0,0.1]); ax1.set_ylim([0,0.25])
ax1.set_xlabel('Prevalence')
ax1.set_ylabel('Positivity')
ax1.set_title('Men 15-24')
ax2.set_xlim([0,0.1]); ax2.set_ylim([0,0.25])
ax2.set_xlabel('Prevalence')
ax2.set_ylabel('Positivity')
ax2.set_title('Women 15-24')

# %%
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

order_m = argsort(percentile(prev_m_laut,50,axis=0)) # order by prevalence in men
order_m = order_m[append(range(0,5),range(146,151))] # Comment-out this line to plot all LAUTS. You will also need to adjust axis sizes.
ax1.errorbar(
    y = range(len(order_m)), 
    x = (percentile(prev_m_laut,50,axis=0))[order_m], 
    xerr=array([percentile(prev_m_laut[:,order_m],50,axis=0) - percentile(prev_m_laut[:,order_m],2.5,axis=0),
            percentile(prev_m_laut[:,order_m],97.5,axis=0) - percentile(prev_m_laut[:,order_m],50,axis=0)]
            ), 
    fmt='.')

ax1.set_ylim(-1, len(order_m)); ax1.set_xlim(0, 0.17)
ax1.set_xlabel('Prevalence in men 15-24')
ax1.grid(True)

order_f = argsort(percentile(prev_f_laut,50,axis=0)) # order by prevalence in women
order_f = order_f[append(range(0,5),range(146,151))] # Comment-out this line to plot all LAUTS. You will also need to adjust axis sizes.
ax2.errorbar(
    y = range(len(order_f)), 
    x = (percentile(prev_f_laut,50,axis=0))[order_f], 
    xerr=array([percentile(prev_f_laut[:,order_f],50,axis=0) - percentile(prev_f_laut[:,order_f],2.5,axis=0),
            percentile(prev_f_laut[:,order_f],97.5,axis=0) - percentile(prev_f_laut[:,order_f],50,axis=0)]
            ), 
    color='r',fmt='.')  

for i in xrange(10):
    ax1.text(0.1, i, alldata.laut[order_m[i]])
    ax2.text(0.1, i, alldata.laut[order_f[i]])

ax2.set_ylim(-1, len(order_f)); ax2.set_xlim(0, 0.17)
ax2.set_xlabel('Prevalence in women 15-24')
ax2.grid(True)

# %% [markdown]
# We also plot inferred prevalence against deprivation (rank of average score from the English Indices of Deprivation 2010):

# %%
code_key
# Out:
#        LAD12CD LAD12CDO                 LAD12NM    CTY12CD  CTY12CDO  \
# 0    E07000004     11UB          Aylesbury Vale  E10000002        11
# 1    E07000005     11UC                Chiltern  E10000002        11
# 2    E07000006     11UE             South Bucks  E10000002        11
# 3    E07000007     11UF                 Wycombe  E10000002        11
# 4    E07000008     12UB               Cambridge  E10000003        12
# 5    E07000009     12UC     East Cambridgeshire  E10000003        12
# 6    E07000010     12UD                 Fenland  E10000003        12
# 7    E07000011     12UE         Huntingdonshire  E10000003        12
# 8    E07000012     12UG    South Cambridgeshire  E10000003        12
# 9    E07000026     16UB               Allerdale  E10000006        16
# 10   E07000027     16UC       Barrow-in-Furness  E10000006        16
# 11   E07000028     16UD                Carlisle  E10000006        16
# 12   E07000029     16UE                Copeland  E10000006        16
# 13   E07000030     16UF                    Eden  E10000006        16
# 14   E07000031     16UG          South Lakeland  E10000006        16
# 15   E07000032     17UB            Amber Valley  E10000007        17
# 16   E07000033     17UC                Bolsover  E10000007        17
# 17   E07000034     17UD            Chesterfield  E10000007        17
# 18   E07000035     17UF        Derbyshire Dales  E10000007        17
# 19   E07000036     17UG                 Erewash  E10000007        17
# 20   E07000037     17UH               High Peak  E10000007        17
# 21   E07000038     17UJ   North East Derbyshire  E10000007        17
# 22   E07000039     17UK        South Derbyshire  E10000007        17
# 23   E07000040     18UB              East Devon  E10000008        18
# 24   E07000041     18UC                  Exeter  E10000008        18
# 25   E07000042     18UD               Mid Devon  E10000008        18
# 26   E07000043     18UE             North Devon  E10000008        18
# 27   E07000044     18UG              South Hams  E10000008        18
# 28   E07000045     18UH             Teignbridge  E10000008        18
# 29   E07000046     18UK                Torridge  E10000008        18
# ..         ...      ...                     ...        ...       ...
# 240  E09000004     00AD                  Bexley        NaN         0
# 241  E09000005     00AE                   Brent        NaN         0
# 242  E09000006     00AF                 Bromley        NaN         0
# 243  E09000007     00AG                  Camden        NaN         0
# 244  E09000008     00AH                 Croydon        NaN         0
# 245  E09000009     00AJ                  Ealing        NaN         0
# 246  E09000010     00AK                 Enfield        NaN         0
# 247  E09000011     00AL               Greenwich        NaN         0
# 248  E09000012     00AM                 Hackney        NaN         0
# 249  E09000013     00AN  Hammersmith and Fulham        NaN         0
# 250  E09000014     00AP                Haringey        NaN         0
# 251  E09000015     00AQ                  Harrow        NaN         0
# 252  E09000016     00AR                Havering        NaN         0
# 253  E09000017     00AS              Hillingdon        NaN         0
# 254  E09000018     00AT                Hounslow        NaN         0
# 255  E09000019     00AU               Islington        NaN         0
# 256  E09000020     00AW  Kensington and Chelsea        NaN         0
# 257  E09000021     00AX    Kingston upon Thames        NaN         0
# 258  E09000022     00AY                 Lambeth        NaN         0
# 259  E09000023     00AZ                Lewisham        NaN         0
# 260  E09000024     00BA                  Merton        NaN         0
# 261  E09000025     00BB                  Newham        NaN         0
# 262  E09000026     00BC               Redbridge        NaN         0
# 263  E09000027     00BD    Richmond upon Thames        NaN         0
# 264  E09000028     00BE               Southwark        NaN         0
# 265  E09000029     00BF                  Sutton        NaN         0
# 266  E09000030     00BG           Tower Hamlets        NaN         0
# 267  E09000031     00BH          Waltham Forest        NaN         0
# 268  E09000032     00BJ              Wandsworth        NaN         0
# 269  E09000033     00BK             Westminster        NaN         0
#
#              CTY12NM
# 0    Buckinghamshire
# 1    Buckinghamshire
# 2    Buckinghamshire
# 3    Buckinghamshire
# 4     Cambridgeshire
# 5     Cambridgeshire
# 6     Cambridgeshire
# 7     Cambridgeshire
# 8     Cambridgeshire
# 9            Cumbria
# 10           Cumbria
# 11           Cumbria
# 12           Cumbria
# 13           Cumbria
# 14           Cumbria
# 15        Derbyshire
# 16        Derbyshire
# 17        Derbyshire
# 18        Derbyshire
# 19        Derbyshire
# 20        Derbyshire
# 21        Derbyshire
# 22        Derbyshire
# 23             Devon
# 24             Devon
# 25             Devon
# 26             Devon
# 27             Devon
# 28             Devon
# 29             Devon
# ..               ...
# 240   Greater London
# 241   Greater London
# 242   Greater London
# 243   Greater London
# 244   Greater London
# 245   Greater London
# 246   Greater London
# 247   Greater London
# 248   Greater London
# 249   Greater London
# 250   Greater London
# 251   Greater London
# 252   Greater London
# 253   Greater London
# 254   Greater London
# 255   Greater London
# 256   Greater London
# 257   Greater London
# 258   Greater London
# 259   Greater London
# 260   Greater London
# 261   Greater London
# 262   Greater London
# 263   Greater London
# 264   Greater London
# 265   Greater London
# 266   Greater London
# 267   Greater London
# 268   Greater London
# 269   Greater London
#
# [270 rows x 6 columns]

# %%
alldata[alldata.laut == 'Bedford']
# Out:
#     laut_code     laut      gor                              phec  \
# 33  E06000055  Bedford  eastern  South Midlands and Hertfordshire
#
#                             pher  tests.male.15-19  tests.male.20-24  \
# 33  Midlands and East of England               677              1252
#
#     tests.male.total  tests.female.15-19  tests.female.20-24  \
# 33              1929                1876                2085
#
#           ...         positives.female.20-24  positives.female.total  \
# 33        ...                            211                     408
#
#     positives.total.15-19  positives.total.20-24  positives.total  \
# 33                    278                    374              652
#
#     population.male.15-19  population.male.20-24  population.female.15-19  \
# 33                   5472                   4768                     4911
#
#     population.female.20-24  population.total
# 33                     4899             20050
#
# [1 rows x 28 columns]

# %%
# lookup table for local authority coding in NCSP vs deprivation data
code_key = pd.read_csv('LAD12_CTY12_EN_LU.csv') # downloaded from https://data.gov.uk/dataset/local-authority-districts-uk-2012-names-and-codes 4 January 2016
# indices of deprivation
deprivation = pd.read_csv('deprivation_indices_2010.csv') # downloaded from downloaded from https://www.gov.uk/government/statistics/english-indices-of-deprivation-2010 1 December 2010

fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

quantiles_m = percentile(prev_m_laut, [50,2.5,97.5], 0)
quantiles_f = percentile(prev_f_laut, [50,2.5,97.5], 0)

for i in alldata.index:
    print i
    print code_key['LAD12CDO'][code_key['LAD12CD'] == alldata.laut_code[i]].tolist()
    if alldata.gor[i] == 'london':
    thisname = code_key['LAD12CDO'][code_key['LAD12CD'] == alldata.laut_code[i]].tolist()[0]
    print thisname
#    print deprivation[u'LA CODE'].tolist()
#    print thisname in deprivation[u'LA CODE'].tolist()
    if thisname in deprivation[u'LA CODE'].tolist():
        print 'yes'
        ax1.plot(int(deprivation[u'Rank of Average Score'][deprivation[u'LA CODE'] == thisname]), # rank of average score for this LAUT
            quantiles_m[0][i],
            '.b'
            )
        ax2.plot(int(deprivation[u'Rank of Average Score'][deprivation[u'LA CODE'] == thisname]), # rank of average score for this LAUT
            quantiles_f[0][i],
            '.r'
            )
# for error bars, rather than points
#         ax1.errorbar(int(deprivation[u'Rank of Average Score'][deprivation[u'LA NAME'] == thisname]), # rank of average score for this LAUT
#             quantiles_m[0][i],
#             yerr = array(quantiles_m[0][i] - quantiles_m[1][i], quantiles_m[2][i] - quantiles_m[0][i]),
#             color = 'b', fmt='.'
#             )
#         ax2.errorbar(int(deprivation[u'Rank of Average Score'][deprivation[u'LA NAME'] == thisname]), # rank of average score for this LAUT
#             quantiles_f[0][i],
#             yerr = array(quantiles_f[0][i] - quantiles_f[1][i], quantiles_f[2][i] - quantiles_f[0][i]),
#             color = 'r', fmt='.'
#             )
    else:
        print thisname
        for j in code_key['LAD12CDO'][code_key.CTY12NM == thisname].tolist(): # for each district in the county (LAUT)
            print j
#             print code_key['LAD12CDO'][code_key['LAD12NM'] == j]
#             thisname = code_key['LAD12CDO'][code_key['LAD12NM'] == j].tolist()
#             print thisname
#            print deprivation[deprivation[u'LA CODE'] == j]
            ax1.plot(int(deprivation[u'Rank of Average Score'][deprivation[u'LA CODE'] == j]), # rank of average score for this LAUT
                     quantiles_m[0][i],
                     '.b')
            ax2.plot(int(deprivation[u'Rank of Average Score'][deprivation[u'LA CODE'] == j]), # rank of average score for this LAUT
                     quantiles_f[0][i],
                     '.r')

ax1.set_xlim([0,350]); ax1.set_ylim([0,0.07])
ax1.set_xlabel('Index of Multiple Deprivation')
ax1.set_ylabel('Prevalence')
ax2.set_xlim([0,350]); ax2.set_ylim([0,0.07])
ax2.set_xlabel('Index of Multiple Deprivation')
ax2.set_ylabel('Prevalence')
# Out:
# 0
# ['00AB']
# 00AB
# yes
# 1
# ['00AC']
# 00AC
# yes
# 2
# ['00AD']
# 00AD
# yes
# 3
# ['00AE']
# 00AE
# yes
# 4
# ['00AF']
# 00AF
# yes
# 5
# ['00AG']
# 00AG
# yes
# 6
# ['00AA']
# 00AA
# yes
# 7
# ['00AH']
# 00AH
# yes
# 8
# ['00AJ']
# 00AJ
# yes
# 9
# ['00AK']
# 00AK
# yes
# 10
# ['00AL']
# 00AL
# yes
# 11
# ['00AM']
# 00AM
# yes
# 12
# ['00AN']
# 00AN
# yes
# 13
# ['00AP']
# 00AP
# yes
# 14
# ['00AQ']
# 00AQ
# yes
# 15
# ['00AR']
# 00AR
# yes
# 16
# ['00AS']
# 00AS
# yes
# 17
# ['00AT']
# 00AT
# yes
# 18
# ['00AU']
# 00AU
# yes
# 19
# ['00AW']
# 00AW
# yes
# 20
# ['00AX']
# 00AX
# yes
# 21
# ['00AY']
# 00AY
# yes
# 22
# ['00AZ']
# 00AZ
# yes
# 23
# ['00BA']
# 00BA
# yes
# 24
# ['00BB']
# 00BB
# yes
# 25
# ['00BC']
# 00BC
# yes
# 26
# ['00BD']
# 00BD
# yes
# 27
# ['00BE']
# 00BE
# yes
# 28
# ['00BF']
# 00BF
# yes
# 29
# ['00BG']
# 00BG
# yes
# 30
# ['00BH']
# 00BH
# yes
# 31
# ['00BJ']
# 00BJ
# yes
# 32
# ['00BK']
# 00BK
# yes
# 33
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-4793b35ab54a> in <module>()
#      14     print i
#      15     print code_key['LAD12CDO'][code_key['LAD12CD'] == alldata.laut_code[i]].tolist()
# ---> 16     thisname = code_key['LAD12CDO'][code_key['LAD12CD'] == alldata.laut_code[i]].tolist()[0]
#      17     print thisname
#      18 #    print deprivation[u'LA CODE'].tolist()
#
# IndexError: list index out of range

# %% [markdown]
# ## Prevalence and incidence
#
# Finally, we plot incidence in each sex against prevalence in the other to examine the effect of infection levels in men on the rate of new infections in women, and vice versa. To make the plots easier to interpret, we restrict our attention to 14 regions with the highest and lowest proportion tested and diagnosed and positivity in men and women.

# %%
hl = ['Blackpool','Bracknell Forest','Cambridgeshire','County Durham','Dudley', \
    'East Riding of Yorkshire','Hillingdon','Kirklees','Lambeth','Portsmouth', \
    'Sandwell','Torbay','Walsall','West Berkshire']
ofinterest = where(alldata.laut.isin(hl))

# %%
fig = plt.figure(figsize = (15,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

x = percentile(prev_m_laut,50,axis=0)
y = percentile(inc_f_laut,50,axis=0)
xerr = abs(percentile(prev_m_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(inc_f_laut,[2.5, 97.5],axis=0) - y)
ax1.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax1.text(x[i], y[i], alldata.laut[i])

x = percentile(prev_f_laut,50,axis=0)
y = percentile(inc_m_laut,50,axis=0)
xerr = abs(percentile(prev_f_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(inc_m_laut,[2.5, 97.5],axis=0) - y)
ax2.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax2.text(x[i], y[i], alldata.laut[i])

ax1.set_xlim(0,0.1); ax2.set_xlim(0,0.1)
ax1.set_xlabel('Prevalence in men'); ax2.set_xlabel('Prevalence in women')
ax1.set_ylim(0,0.6); ax2.set_ylim(0,0.6)
ax1.set_ylabel('Incidence in women'); ax2.set_ylabel('Incidence in men')

# %% [markdown]
# An natural question is why some LAUTs have higher incidence and prevalence than others. One possibility is that higher screening rates in some areas lower prevalence and incidence. To investigate this, plot incidence against screening in men and women:

# %%
max(percentile(scr_f_laut,50,axis=0))

# %%
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

x = percentile(scr_m_laut,50,axis=0)
y = percentile(inc_m_laut,50,axis=0)
xerr = abs(percentile(scr_m_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(inc_m_laut,[2.5, 97.5],axis=0) - y)
ax1.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax1.text(x[i], y[i], alldata.laut[i])
ax1.set_xlabel('Screening in men'); ax1.set_ylabel('Incidence in men')

x = percentile(scr_f_laut,50,axis=0)
y = percentile(inc_m_laut,50,axis=0)
xerr = abs(percentile(scr_f_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(inc_m_laut,[2.5, 97.5],axis=0) - y)
ax2.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax2.text(x[i], y[i], alldata.laut[i])
ax2.set_xlabel('Screening in women'); ax2.set_ylabel('Incidence in men')

x = percentile(scr_m_laut,50,axis=0)
y = percentile(inc_f_laut,50,axis=0)
xerr = abs(percentile(scr_m_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(inc_f_laut,[2.5, 97.5],axis=0) - y)
ax3.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax3.text(x[i], y[i], alldata.laut[i])
ax3.set_xlabel('Screening in men'); ax3.set_ylabel('Incidence in women')

x = percentile(scr_f_laut,50,axis=0)
y = percentile(inc_f_laut,50,axis=0)
xerr = abs(percentile(scr_f_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(inc_f_laut,[2.5, 97.5],axis=0) - y)
ax4.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax4.text(x[i], y[i], alldata.laut[i])
ax4.set_xlabel('Screening in women'); ax4.set_ylabel('Incidence in women')

# %% [markdown]
# In fact, areas with more screening tend to have higher incidence, although the correlations are fairly weak. We also examine the relationship with prevalence:

# %%
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

x = percentile(scr_m_laut,50,axis=0)
y = percentile(prev_m_laut,50,axis=0)
xerr = abs(percentile(scr_m_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(prev_m_laut,[2.5, 97.5],axis=0) - y)
ax1.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax1.text(x[i], y[i], alldata.laut[i])
ax1.set_xlabel('Screening in men'); ax1.set_ylabel('Prevalence in men')

x = percentile(scr_f_laut,50,axis=0)
y = percentile(prev_m_laut,50,axis=0)
xerr = abs(percentile(scr_f_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(prev_m_laut,[2.5, 97.5],axis=0) - y)
ax2.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax2.text(x[i], y[i], alldata.laut[i])
ax2.set_xlabel('Screening in women'); ax2.set_ylabel('Prevalence in men')

x = percentile(scr_m_laut,50,axis=0)
y = percentile(prev_f_laut,50,axis=0)
xerr = abs(percentile(scr_m_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(prev_f_laut,[2.5, 97.5],axis=0) - y)
ax3.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax3.text(x[i], y[i], alldata.laut[i])
ax3.set_xlabel('Screening in men'); ax3.set_ylabel('Prevalence in women')

x = percentile(scr_f_laut,50,axis=0)
y = percentile(prev_f_laut,50,axis=0)
xerr = abs(percentile(scr_f_laut,[2.5, 97.5],axis=0) - x)
yerr = abs(percentile(prev_f_laut,[2.5, 97.5],axis=0) - y)
ax4.errorbar(x[ofinterest], y[ofinterest], xerr=squeeze(xerr[:,ofinterest]), yerr=squeeze(yerr[:,ofinterest]), fmt='.')
for i in list(ofinterest[0]):
    ax4.text(x[i], y[i], alldata.laut[i])
ax4.set_xlabel('Screening in women'); ax4.set_ylabel('Prevalence in women')

# %% [markdown]
# Prevalence is also generally higher in areas with more screening, although the relationship is complex.
